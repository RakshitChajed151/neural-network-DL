# %% [markdown]
# <a href="https://colab.research.google.com/github/RakshitChajed151/neural-network-DL/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x=np.array(8)
print(x)
# Out:
# 8

# %%
vec=[11,22,33,44,55]
print(vec)
# Out:
# [11, 22, 33, 44, 55]

# %%
x=[2,4,6,8]
for element in x:
 print(element)
# Out:
# 2
# 4
# 6
# 8

# %%
x=np.array([2,4,6,8])
print(x)
print(x.ndim)
print(x.shape)
# Out:
# [2 4 6 8]
# 1
# (4,)

# %%
x=np.array([[11,22,33],[44,55,66],[77,88,99]])
print(x)
print(x.ndim)
print(x.shape)
print(x.size)
# Out:
# [[11 22 33]
#  [44 55 66]
#  [77 88 99]]
# 2
# (3, 3)
# 9

# %%
import tensorflow as tf
string_tensor=tf.constant("hello,beautiful")
print(string_tensor)
string_length = tf.strings.length(string_tensor)
print("String Lengths:", string_length.numpy())
# Out:
# tf.Tensor(b'hello,beautiful', shape=(), dtype=string)
# String Lengths: 15

# %%
x = np.array([1,2,3])
print(x.reshape(1,3))   # Row vector
print(x.reshape(3,1))
# Out:
# [[1 2 3]]
# [[1]
#  [2]
#  [3]]
